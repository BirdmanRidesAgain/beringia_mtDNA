# %% [markdown]
# # Annotation stats

# %% [markdown]
# -----
# | Name | Date |
# | - | - |
# | Keiler Collier | 30 April 2026 |
# -----

# %% [markdown]
# ## Introduction
#
#
# -----

# %% [markdown]
# ## Methods
# -----

# %% [markdown]
# ## Results
# -----

# %% [markdown]
# ## Discussion
# -----
